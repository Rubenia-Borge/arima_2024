# %%
# Dataset
# Load data as a series and visualize data
# Load the data as a series
# Plot to see the trend

from pandas import read_csv
#from pandas import datetime
from matplotlib import pyplot
from datetime import datetime

series = read_csv('belize_tb_data.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(series.head())
# Out:
# year
# 1980-01-01     21
# 1981-01-01     33
# 1982-01-01     44
# 1983-01-01    140
# 1984-01-01     35
# Name: cases, dtype: int64

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = read_csv('belize_tb_data.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
series = read_csv('belize_tb_data.csv', header=0, index_col=0)
plot_pacf(series, lags=20)
pyplot.show()

# %%
from pandas import read_csv
from datetime import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

series = read_csv('belize.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
autocorrelation_plot(series)
pyplot.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
sm.graphics.tsa.plot_acf(series.values.squeeze(), lags=40)
plt.show()
